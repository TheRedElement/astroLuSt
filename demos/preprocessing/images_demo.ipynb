# %%
import importlib
import matplotlib.pyplot as plt
from keras.datasets import mnist
import sys
sys.path.append("../../")

from astroLuSt.preprocessing import images as alprim
from astroLuSt.styles import plot_styles as alstps

importlib.reload(alprim)

importlib.reload(alstps)

#style for plotting
_ = alstps.tre_light()
# Out:
# 2024-11-08 18:41:10.654733: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
(X, y), (_, _) = mnist.load_data()
X = X[:20]
print(X.shape)
# Out:
# (20, 28, 28)

# %% [markdown]
# # `Images2Patches`
# * splitting

# %%
I2P = alprim.Images2Patches(xpatches=4, ypatches=2)
I2P.fit(X)
X_patched = I2P.transform(X)

im2plot = 0
fig = plt.figure(figsize=(9,5))
fig, axs = I2P.plot_result(
    X_patched[im2plot],
    X_in=X[im2plot],
    fig=fig,
)
for ax in axs: ax.set_aspect("equal")
fig.tight_layout()
plt.show()
