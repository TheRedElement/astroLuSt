# %%
import importlib
import matplotlib.pyplot as plt
import numpy as np

from astroLuSt.synthetics import dataaugmentation as alsyda
from astroLuSt.styles import plot_styles as alstps

import logging
from astroLuSt.allogging import setup_logger
setup_logger(level=logging.INFO)

importlib.reload(alsyda)
importlib.reload(alstps)

#style for plotting
_ = alstps.tre_light()

# %% [markdown]
# # AugmentAxis

# %% [markdown]
# ### Generate a dataset
#
# This dataset will contian the following:
# - `nsamples` samples
# - `ncols` datapoints along first axes (columns)
# - `nrows` datapoints along second axes (rows)
# - `nchannels` number of channels (values per cell)
#
# each sample consists of `ncols * nrows * nchannels` datapoints.
#
# For the 3d case one just has no `nchannels` everything else is the same as for the 4d case.

# %%
def generate_4d(
    shape:tuple=None,
    xmin:float=0, xmax:float=1,
    func=None
    ):
    if shape is None:
        shape = (1,20,1,1)
    if func is None:
        func = lambda x: x
    X = np.empty(shape)
    for i, xi in enumerate(X):
        x_ = np.linspace(np.zeros((X.shape[-2],X.shape[-1]))+xmin, xmax, X.shape[1])
        
        hshift = np.random.rand(x_.shape[1]).reshape(1,-1,1)
        vshift = np.zeros_like(x_)+i
        cnoise = np.random.randn(x_.shape[0], x_.shape[2]).reshape(50,1,-1)*0.1
        vshift[:,1,:] += X.shape[0]
        X[i] = func(x_+hshift) + vshift + cnoise

    return X

X = generate_4d(
    shape=(23,50,2,3),
    xmin=0, xmax=2*np.pi,
    # func=np.sin,
    func=None,
)
X3d = X[:,:,0,0]
X3d = X3d.reshape(*X3d.shape,1)
y = np.random.choice([0,1,2],size=(X.shape[0],1), replace=True,  p=[0.5,0.3,0.2])

print(X.shape)
print(X3d.shape)
print(y.shape)
#visualize
fig = plt.figure()
ax1 = fig.add_subplot(111)
for x in X:
    ax1.plot(x[:,0,:], 'C0-')
    # ax1.plot(x[:,1,0], 'r-')
    ax1.plot(x[:,1,:], 'C1-')
ax1.set_xlabel('index')
ax1.set_ylabel('y')
plt.show()
# Out:
# (23, 50, 2, 3)
# (23, 50, 1)
# (23, 1)

# %% [markdown]
# ### Application on 4d data

# %%
importlib.reload(alsyda)

AA = alsyda.AugmentAxis(
    nsamples=100, ntransformations=-3,
    shift=(0,20), methods=None, transform_order=None,
    npoints=5, neighbors=False,
    fill_value_obscure=0, fill_value_range=(0,1),
    cutout_start=0, cutout_size=(4,6),
    interpkind=None, fill_value_crop=None,
    noise_mag=(0,0.5),
    feature_range_min=None, feature_range_max=None,
    axis=(0),
    seed=None,
    verbose=1,
)
print(AA)

AA.fit(X)
AA.random_transform(X[0], axis=(0,1))
X_new, y_new, y1  = AA.flow(X,
    y=y,
    X_misc=[y],
    sample_weights=None, class_weights=[0.1,0.4,0.5]
)

u_, c_ = np.unique(y_new, return_counts=True)
print(u_, c_/len(y_new))

#visualize
fig = plt.figure(figsize=(9,3))
ax1 = fig.add_subplot(111)
#4d
# ax1.plot(X[0,:,0,:], 'C0:')
# ax1.plot(X[0,:,1,:], 'C1:')
ax1.plot(X_new[0,:,0,0], 'C0-')
ax1.plot(X_new[0,:,0,1], 'C1-')
ax1.plot(X_new[0,:,0,2], 'C2-')
ax1.plot(X_new[0,:,1,0], 'C0--')
ax1.plot(X_new[0,:,1,1], 'C1--')
ax1.plot(X_new[0,:,1,2], 'C2--')


ax1.set_xlabel('index')
ax1.set_ylabel('y')
plt.show()
# Out:
# INFO    : 2025-08-05 15:25:21,348, astroLuSt.synthetics.dataaugmentation [MainProcess ]: Applied the following transformations: ['flip_axis_t' 'rescale_t' 'crop_t' 'shift_features_t'] (AugmentAxis)
# INFO    : 2025-08-05 15:25:21,348, astroLuSt.synthetics.dataaugmentation [MainProcess ]: Generating 100 new samples... (AugmentAxis)
# INFO    : 2025-08-05 15:25:21,349, astroLuSt.synthetics.dataaugmentation [MainProcess ]: Applied the following transformations: ['add_noise_t' 'rescale_t' 'flip_axis_t' 'shift_features_t'] (AugmentAxis)
# INFO    : 2025-08-05 15:25:21,350, astroLuSt.synthetics.dataaugmentation [MainProcess ]: Applied the following transformations: ['flip_axis_t' 'crop_t' 'shift_features_t' 'obscure_observations_t'] (AugmentAxis)
# INFO    : 2025-08-05 15:25:21,351, astroLuSt.synthetics.dataaugmentation [MainProcess ]: Applied the following transformations: ['flip_axis_t' 'rescale_t' 'crop_t' 'add_noise_t'] (AugmentAxis)
# INFO    : 2025-08-05 15:25:21,352, astroLuSt.synthetics.dataaugmentation [MainProcess ]: Applied the following transformations: ['crop_t' 'shift_features_t' 'add_noise_t' 'flip_axis_t'] (AugmentAxis)
# INFO    : 2025-08-05 15:25:21,354, astroLuSt.synthetics.dataaugmentation [MainProcess ]: Applied the following transformations: ['add_noise_t' 'rescale_t' 'obscure_observations_t' 'crop_t'] (AugmentAxis)
# INFO    : 2025-08-05 15:25:21,355, astroLuSt.synthetics.dataaugmentation [MainProcess ]: Applied the following transformations: ['rescale_t' 'shift_features_t' 'flip_axis_t' 'obscure_observations_t'] (AugmentAxis)
# INFO    : 2025-08-05 15:25:21,356, astroLuSt.synthetics.dataaugmentation [MainProcess ]: Applied the following transformations: ['rescale_t' 'shift_features_t' 'obscure_observations_t' 'crop_t'] (AugmentAxis)
# INFO    : 2025-08-05 15:25:21,357, astroLuSt.synthetics.dataaugmentation [MainProcess ]: Applied the following transformations: ['obscure_observations_t' 'flip_axis_t' 'shift_features_t' 'add_noise_t'] (AugmentAxis)
# INFO    : 2025-08-05 15:25:21,358, astroLuSt.synthetics.dataaugmentation [MainProcess ]: Applied the following transformations: ['obscure_observations_t' 'shift_features_t' 'crop_t' 'add_noise_t'] (AugmentAxis)
# INFO    : 2025-08-05 15:25:21,359, astroLuSt.synthetics.dataaugmentation [MainProcess ]: Applied the following transformations: ['rescale_t' 'crop_t' 'obscure_observations_t' 'add_noise_t'] (AugmentAxis)
# INFO    : 2025-08-05 15:25:21,361, astroLuSt.synthetics.dataaugmentation [MainProcess ]: Applied the following transformations: ['shift_features_t' 'rescale_t' 'add_noise_t' 'obscure_observations_t'] (AugmentAxis)
# INFO    : 2025-08-05 15:25:21,362, astroLuSt.synthetics.dataaugmentation [MainProcess ]: Applied the following transformations: ['flip_axis_t' 'shift_features_t' 'obscure_observations_t' 'rescale_t'] (AugmentAxis)
# INFO    : 2025-08-05 15:25:21,364, astroLuSt.synthetics.dataaugmentation [MainProcess ]: Applied the following transformations: ['obscure_observations_t' 'rescale_t' 'add_noise_t' 'shift_features_t'] (AugmentAxis)
# INFO    : 2025-08-05 15:25:21,367, astroLuSt.synthetics.dataaugmentation [MainProcess ]: Applied the following transformations: ['flip_axis_t' 'shift_features_t' 'obscure_observations_t' 'crop_t'] (AugmentAxis)
# INFO    : 2025-08-05 15:25:21,370, astroLuSt.synthetics.dataaugmentation [MainProcess ]: Applied the following transformations: ['add_noise_t' 'shift_features_t' 'rescale_t' 'crop_t'] (AugmentAxis)
# INFO    : 2025-08-05 15:25:21,371, astroLuSt.synthetics.dataaugmentation [MainProcess ]: Applied the following transformations: ['shift_features_t' 'obscure_observations_t' 'rescale_t' 'add_noise_t'] (AugmentAxis)
# INFO    : 2025-08-05 15:25:21,373, astroLuSt.synthetics.dataaugmentation [MainProcess ]: Applied the following transformations: ['rescale_t' 'obscure_observations_t' 'crop_t' 'shift_features_t'] (AugmentAxis)
# INFO    : 2025-08-05 15:25:21,374, astroLuSt.synthetics.dataaugmentation [MainProcess ]: Applied the following transformations: ['flip_axis_t' 'add_noise_t' 'obscure_observations_t' 'shift_features_t'] (AugmentAxis)
# INFO    : 2025-08-05 15:25:21,376, astroLuSt.synthetics.dataaugmentation [MainProcess ]: Applied the following transformations: ['flip_axis_t' 'rescale_t' 'add_noise_t' 'crop_t'] (AugmentAxis)
# INFO    : 2025-08-05 15:25:21,377, astroLuSt.synthetics.dataaugmentation [MainProcess ]: Applied the following transformations: ['crop_t' 'add_noise_t' 'rescale_t' 'obscure_observations_t'] (AugmentAxis)
# INFO    : 2025-08-05 15:25:21,378, astroLuSt.synthetics.dataaugmentation [MainProcess ]: Applied the following transformations: ['shift_features_t' 'obscure_observations_t' 'rescale_t' 'add_noise_t'] (AugmentAxis)
# INFO    : 2025-08-05 15:25:21,379, astroLuSt.synthetics.dataaugmentation [MainProcess ]: Applied the following transformations: ['add_noise_t' 'rescale_t' 'shift_features_t' 'flip_axis_t'] (AugmentAxis)
# INFO    : 2025-08-05 15:25:21,380, astroLuSt.synthetics.dataaugmentation [MainProcess ]: Applied the following transformations: ['shift_features_t' 'obscure_observations_t' 'rescale_t' 'add_noise_t'] (AugmentAxis)
# INFO    : 2025-08-05 15:25:21,382, astroLuSt.synthetics.dataaugmentation [MainProcess ]: Applied the following transformations: ['shift_features_t' 'rescale_t' 'crop_t' 'obscure_observations_t'] (AugmentAxis)
# INFO    : 2025-08-05 15:25:21,384, astroLuSt.synthetics.dataaugmentation [MainProcess ]: Applied the following transformations: ['rescale_t' 'crop_t' 'flip_axis_t' 'add_noise_t'] (AugmentAxis)
# INFO    : 2025-08-05 15:25:21,386, astroLuSt.synthetics.dataaugmentation [MainProcess ]: Applied the following transformations: ['flip_axis_t' 'shift_features_t' 'crop_t' 'obscure_observations_t'] (AugmentAxis)
# INFO    : 2025-08-05 15:25:21,388, astroLuSt.synthetics.dataaugmentation [MainProcess ]: Applied the following transformations: ['shift_features_t' 'add_noise_t' 'crop_t' 'flip_axis_t'] (AugmentAxis)
# INFO    : 2025-08-05 15:25:21,389, astroLuSt.synthetics.dataaugmentation [MainProcess ]: Applied the following transformations: ['add_noise_t' 'flip_axis_t' 'shift_features_t' 'obscure_observations_t'] (AugmentAxis)
# INFO    : 2025-08-05 15:25:21,390, astroLuSt.synthetics.dataaugmentation [MainProcess ]: Applied the following transformations: ['flip_axis_t' 'obscure_observations_t' 'crop_t' 'add_noise_t'] (AugmentAxis)
# INFO    : 2025-08-05 15:25:21,392, astroLuSt.synthetics.dataaugmentation [MainProcess ]: Applied the following transformations: ['add_noise_t' 'shift_features_t' 'obscure_observations_t' 'flip_axis_t'] (AugmentAxis)
# INFO    : 2025-08-05 15:25:21,393, astroLuSt.synthetics.dataaugmentation [MainProcess ]: Applied the following transformations: ['crop_t' 'add_noise_t' 'rescale_t' 'obscure_observations_t'] (AugmentAxis)
# INFO    : 2025-08-05 15:25:21,395, astroLuSt.synthetics.dataaugmentation [MainProcess ]: Applied the following transformations: ['add_noise_t' 'flip_axis_t' 'obscure_observations_t' 'crop_t'] (AugmentAxis)
# INFO    : 2025-08-05 15:25:21,396, astroLuSt.synthetics.dataaugmentation [MainProcess ]: Applied the following transformations: ['shift_features_t' 'add_noise_t' 'crop_t' 'obscure_observations_t'] (AugmentAxis)
# INFO    : 2025-08-05 15:25:21,398, astroLuSt.synthetics.dataaugmentation [MainProcess ]: Applied the following transformations: ['shift_features_t' 'crop_t' 'obscure_observations_t' 'add_noise_t'] (AugmentAxis)
# INFO    : 2025-08-05 15:25:21,400, astroLuSt.synthetics.dataaugmentation [MainProcess ]: Applied the following transformations: ['add_noise_t' 'crop_t' 'shift_features_t' 'obscure_observations_t'] (AugmentAxis)
# INFO    : 2025-08-05 15:25:21,402, astroLuSt.synthetics.dataaugmentation [MainProcess ]: Applied the following transformations: ['obscure_observations_t' 'flip_axis_t' 'shift_features_t' 'crop_t'] (AugmentAxis)
# INFO    : 2025-08-05 15:25:21,403, astroLuSt.synthetics.dataaugmentation [MainProcess ]: Applied the following transformations: ['shift_features_t' 'add_noise_t' 'rescale_t' 'crop_t'] (AugmentAxis)
# INFO    : 2025-08-05 15:25:21,405, astroLuSt.synthetics.dataaugmentation [MainProcess ]: Applied the following transformations: ['rescale_t' 'add_noise_t' 'shift_features_t' 'crop_t'] (AugmentAxis)
# INFO    : 2025-08-05 15:25:21,406, astroLuSt.synthetics.dataaugmentation [MainProcess ]: Applied the following transformations: ['flip_axis_t' 'add_noise_t' 'crop_t' 'shift_features_t'] (AugmentAxis)
# INFO    : 2025-08-05 15:25:21,407, astroLuSt.synthetics.dataaugmentation [MainProcess ]: Applied the following transformations: ['obscure_observations_t' 'crop_t' 'rescale_t' 'flip_axis_t'] (AugmentAxis)
# INFO    : 2025-08-05 15:25:21,408, astroLuSt.synthetics.dataaugmentation [MainProcess ]: Applied the following transformations: ['shift_features_t' 'rescale_t' 'flip_axis_t' 'add_noise_t'] (AugmentAxis)
# INFO    : 2025-08-05 15:25:21,410, astroLuSt.synthetics.dataaugmentation [MainProcess ]: Applied the following transformations: ['rescale_t' 'add_noise_t' 'obscure_observations_t' 'shift_features_t'] (AugmentAxis)
# INFO    : 2025-08-05 15:25:21,411, astroLuSt.synthetics.dataaugmentation [MainProcess ]: Applied the following transformations: ['obscure_observations_t' 'crop_t' 'flip_axis_t' 'rescale_t'] (AugmentAxis)
# INFO    : 2025-08-05 15:25:21,412, astroLuSt.synthetics.dataaugmentation [MainProcess ]: Applied the following transformations: ['crop_t' 'flip_axis_t' 'shift_features_t' 'add_noise_t'] (AugmentAxis)
# INFO    : 2025-08-05 15:25:21,413, astroLuSt.synthetics.dataaugmentation [MainProcess ]: Applied the following transformations: ['flip_axis_t' 'obscure_observations_t' 'rescale_t' 'add_noise_t'] (AugmentAxis)
# INFO    : 2025-08-05 15:25:21,415, astroLuSt.synthetics.dataaugmentation [MainProcess ]: Applied the following transformations: ['add_noise_t' 'obscure_observations_t' 'flip_axis_t' 'crop_t'] (AugmentAxis)
# INFO    : 2025-08-05 15:25:21,416, astroLuSt.synthetics.dataaugmentation [MainProcess ]: Applied the following transformations: ['obscure_observations_t' 'shift_features_t' 'crop_t' 'rescale_t'] (AugmentAxis)
# INFO    : 2025-08-05 15:25:21,418, astroLuSt.synthetics.dataaugmentation [MainProcess ]: Applied the following transformations: ['obscure_observations_t' 'shift_features_t' 'add_noise_t' 'flip_axis_t'] (AugmentAxis)
# INFO    : 2025-08-05 15:25:21,420, astroLuSt.synthetics.dataaugmentation [MainProcess ]: Applied the following transformations: ['crop_t' 'add_noise_t' 'shift_features_t' 'obscure_observations_t'] (AugmentAxis)
# INFO    : 2025-08-05 15:25:21,421, astroLuSt.synthetics.dataaugmentation [MainProcess ]: Applied the following transformations: ['rescale_t' 'add_noise_t' 'shift_features_t' 'crop_t'] (AugmentAxis)
# INFO    : 2025-08-05 15:25:21,423, astroLuSt.synthetics.dataaugmentation [MainProcess ]: Applied the following transformations: ['add_noise_t' 'shift_features_t' 'crop_t' 'rescale_t'] (AugmentAxis)
# INFO    : 2025-08-05 15:25:21,426, astroLuSt.synthetics.dataaugmentation [MainProcess ]: Applied the following transformations: ['flip_axis_t' 'crop_t' 'add_noise_t' 'rescale_t'] (AugmentAxis)
# INFO    : 2025-08-05 15:25:21,428, astroLuSt.synthetics.dataaugmentation [MainProcess ]: Applied the following transformations: ['obscure_observations_t' 'crop_t' 'add_noise_t' 'shift_features_t'] (AugmentAxis)
# INFO    : 2025-08-05 15:25:21,431, astroLuSt.synthetics.dataaugmentation [MainProcess ]: Applied the following transformations: ['rescale_t' 'crop_t' 'flip_axis_t' 'shift_features_t'] (AugmentAxis)
# INFO    : 2025-08-05 15:25:21,434, astroLuSt.synthetics.dataaugmentation [MainProcess ]: Applied the following transformations: ['flip_axis_t' 'crop_t' 'rescale_t' 'obscure_observations_t'] (AugmentAxis)
# INFO    : 2025-08-05 15:25:21,435, astroLuSt.synthetics.dataaugmentation [MainProcess ]: Applied the following transformations: ['flip_axis_t' 'shift_features_t' 'crop_t' 'add_noise_t'] (AugmentAxis)
# INFO    : 2025-08-05 15:25:21,437, astroLuSt.synthetics.dataaugmentation [MainProcess ]: Applied the following transformations: ['obscure_observations_t' 'shift_features_t' 'flip_axis_t' 'rescale_t'] (AugmentAxis)
# INFO    : 2025-08-05 15:25:21,440, astroLuSt.synthetics.dataaugmentation [MainProcess ]: Applied the following transformations: ['add_noise_t' 'rescale_t' 'flip_axis_t' 'crop_t'] (AugmentAxis)
# INFO    : 2025-08-05 15:25:21,442, astroLuSt.synthetics.dataaugmentation [MainProcess ]: Applied the following transformations: ['add_noise_t' 'rescale_t' 'flip_axis_t' 'crop_t'] (AugmentAxis)
# INFO    : 2025-08-05 15:25:21,443, astroLuSt.synthetics.dataaugmentation [MainProcess ]: Applied the following transformations: ['obscure_observations_t' 'flip_axis_t' 'add_noise_t' 'shift_features_t'] (AugmentAxis)
# INFO    : 2025-08-05 15:25:21,445, astroLuSt.synthetics.dataaugmentation [MainProcess ]: Applied the following transformations: ['add_noise_t' 'rescale_t' 'crop_t' 'shift_features_t'] (AugmentAxis)
# INFO    : 2025-08-05 15:25:21,447, astroLuSt.synthetics.dataaugmentation [MainProcess ]: Applied the following transformations: ['rescale_t' 'shift_features_t' 'crop_t' 'add_noise_t'] (AugmentAxis)
# INFO    : 2025-08-05 15:25:21,449, astroLuSt.synthetics.dataaugmentation [MainProcess ]: Applied the following transformations: ['obscure_observations_t' 'add_noise_t' 'shift_features_t' 'flip_axis_t'] (AugmentAxis)
# INFO    : 2025-08-05 15:25:21,450, astroLuSt.synthetics.dataaugmentation [MainProcess ]: Applied the following transformations: ['shift_features_t' 'flip_axis_t' 'rescale_t' 'obscure_observations_t'] (AugmentAxis)
# INFO    : 2025-08-05 15:25:21,451, astroLuSt.synthetics.dataaugmentation [MainProcess ]: Applied the following transformations: ['flip_axis_t' 'obscure_observations_t' 'shift_features_t' 'crop_t'] (AugmentAxis)
# INFO    : 2025-08-05 15:25:21,453, astroLuSt.synthetics.dataaugmentation [MainProcess ]: Applied the following transformations: ['crop_t' 'shift_features_t' 'add_noise_t' 'obscure_observations_t'] (AugmentAxis)
# INFO    : 2025-08-05 15:25:21,455, astroLuSt.synthetics.dataaugmentation [MainProcess ]: Applied the following transformations: ['obscure_observations_t' 'rescale_t' 'crop_t' 'add_noise_t'] (AugmentAxis)
# INFO    : 2025-08-05 15:25:21,457, astroLuSt.synthetics.dataaugmentation [MainProcess ]: Applied the following transformations: ['obscure_observations_t' 'flip_axis_t' 'crop_t' 'shift_features_t'] (AugmentAxis)
# INFO    : 2025-08-05 15:25:21,458, astroLuSt.synthetics.dataaugmentation [MainProcess ]: Applied the following transformations: ['flip_axis_t' 'obscure_observations_t' 'shift_features_t' 'crop_t'] (AugmentAxis)
# INFO    : 2025-08-05 15:25:21,461, astroLuSt.synthetics.dataaugmentation [MainProcess ]: Applied the following transformations: ['flip_axis_t' 'obscure_observations_t' 'shift_features_t' 'add_noise_t'] (AugmentAxis)
# INFO    : 2025-08-05 15:25:21,463, astroLuSt.synthetics.dataaugmentation [MainProcess ]: Applied the following transformations: ['add_noise_t' 'flip_axis_t' 'obscure_observations_t' 'crop_t'] (AugmentAxis)
# INFO    : 2025-08-05 15:25:21,466, astroLuSt.synthetics.dataaugmentation [MainProcess ]: Applied the following transformations: ['add_noise_t' 'crop_t' 'shift_features_t' 'flip_axis_t'] (AugmentAxis)
# INFO    : 2025-08-05 15:25:21,468, astroLuSt.synthetics.dataaugmentation [MainProcess ]: Applied the following transformations: ['shift_features_t' 'crop_t' 'obscure_observations_t' 'rescale_t'] (AugmentAxis)
# INFO    : 2025-08-05 15:25:21,469, astroLuSt.synthetics.dataaugmentation [MainProcess ]: Applied the following transformations: ['obscure_observations_t' 'crop_t' 'rescale_t' 'shift_features_t'] (AugmentAxis)
# INFO    : 2025-08-05 15:25:21,471, astroLuSt.synthetics.dataaugmentation [MainProcess ]: Applied the following transformations: ['obscure_observations_t' 'rescale_t' 'crop_t' 'add_noise_t'] (AugmentAxis)
# INFO    : 2025-08-05 15:25:21,472, astroLuSt.synthetics.dataaugmentation [MainProcess ]: Applied the following transformations: ['rescale_t' 'add_noise_t' 'crop_t' 'obscure_observations_t'] (AugmentAxis)
# INFO    : 2025-08-05 15:25:21,474, astroLuSt.synthetics.dataaugmentation [MainProcess ]: Applied the following transformations: ['shift_features_t' 'flip_axis_t' 'obscure_observations_t' 'rescale_t'] (AugmentAxis)
# INFO    : 2025-08-05 15:25:21,476, astroLuSt.synthetics.dataaugmentation [MainProcess ]: Applied the following transformations: ['shift_features_t' 'flip_axis_t' 'crop_t' 'rescale_t'] (AugmentAxis)
# INFO    : 2025-08-05 15:25:21,477, astroLuSt.synthetics.dataaugmentation [MainProcess ]: Applied the following transformations: ['rescale_t' 'add_noise_t' 'crop_t' 'flip_axis_t'] (AugmentAxis)
# INFO    : 2025-08-05 15:25:21,479, astroLuSt.synthetics.dataaugmentation [MainProcess ]: Applied the following transformations: ['add_noise_t' 'crop_t' 'flip_axis_t' 'rescale_t'] (AugmentAxis)
# INFO    : 2025-08-05 15:25:21,480, astroLuSt.synthetics.dataaugmentation [MainProcess ]: Applied the following transformations: ['add_noise_t' 'obscure_observations_t' 'shift_features_t' 'crop_t'] (AugmentAxis)
# INFO    : 2025-08-05 15:25:21,482, astroLuSt.synthetics.dataaugmentation [MainProcess ]: Applied the following transformations: ['crop_t' 'rescale_t' 'shift_features_t' 'add_noise_t'] (AugmentAxis)
# INFO    : 2025-08-05 15:25:21,484, astroLuSt.synthetics.dataaugmentation [MainProcess ]: Applied the following transformations: ['shift_features_t' 'rescale_t' 'add_noise_t' 'flip_axis_t'] (AugmentAxis)
# INFO    : 2025-08-05 15:25:21,485, astroLuSt.synthetics.dataaugmentation [MainProcess ]: Applied the following transformations: ['add_noise_t' 'crop_t' 'shift_features_t' 'obscure_observations_t'] (AugmentAxis)
# INFO    : 2025-08-05 15:25:21,487, astroLuSt.synthetics.dataaugmentation [MainProcess ]: Applied the following transformations: ['rescale_t' 'obscure_observations_t' 'shift_features_t' 'crop_t'] (AugmentAxis)
# INFO    : 2025-08-05 15:25:21,489, astroLuSt.synthetics.dataaugmentation [MainProcess ]: Applied the following transformations: ['flip_axis_t' 'obscure_observations_t' 'add_noise_t' 'rescale_t'] (AugmentAxis)
# INFO    : 2025-08-05 15:25:21,491, astroLuSt.synthetics.dataaugmentation [MainProcess ]: Applied the following transformations: ['flip_axis_t' 'shift_features_t' 'crop_t' 'rescale_t'] (AugmentAxis)
# INFO    : 2025-08-05 15:25:21,493, astroLuSt.synthetics.dataaugmentation [MainProcess ]: Applied the following transformations: ['crop_t' 'flip_axis_t' 'rescale_t' 'obscure_observations_t'] (AugmentAxis)
# INFO    : 2025-08-05 15:25:21,494, astroLuSt.synthetics.dataaugmentation [MainProcess ]: Applied the following transformations: ['rescale_t' 'add_noise_t' 'flip_axis_t' 'obscure_observations_t'] (AugmentAxis)
# INFO    : 2025-08-05 15:25:21,496, astroLuSt.synthetics.dataaugmentation [MainProcess ]: Applied the following transformations: ['shift_features_t' 'flip_axis_t' 'obscure_observations_t' 'crop_t'] (AugmentAxis)
# INFO    : 2025-08-05 15:25:21,498, astroLuSt.synthetics.dataaugmentation [MainProcess ]: Applied the following transformations: ['obscure_observations_t' 'shift_features_t' 'crop_t' 'rescale_t'] (AugmentAxis)
# INFO    : 2025-08-05 15:25:21,500, astroLuSt.synthetics.dataaugmentation [MainProcess ]: Applied the following transformations: ['rescale_t' 'obscure_observations_t' 'shift_features_t' 'add_noise_t'] (AugmentAxis)
# INFO    : 2025-08-05 15:25:21,502, astroLuSt.synthetics.dataaugmentation [MainProcess ]: Applied the following transformations: ['obscure_observations_t' 'rescale_t' 'crop_t' 'shift_features_t'] (AugmentAxis)
# INFO    : 2025-08-05 15:25:21,503, astroLuSt.synthetics.dataaugmentation [MainProcess ]: Applied the following transformations: ['rescale_t' 'add_noise_t' 'crop_t' 'shift_features_t'] (AugmentAxis)
# INFO    : 2025-08-05 15:25:21,504, astroLuSt.synthetics.dataaugmentation [MainProcess ]: Applied the following transformations: ['flip_axis_t' 'rescale_t' 'obscure_observations_t' 'add_noise_t'] (AugmentAxis)
# INFO    : 2025-08-05 15:25:21,505, astroLuSt.synthetics.dataaugmentation [MainProcess ]: Applied the following transformations: ['rescale_t' 'crop_t' 'shift_features_t' 'add_noise_t'] (AugmentAxis)
# INFO    : 2025-08-05 15:25:21,505, astroLuSt.synthetics.dataaugmentation [MainProcess ]: Applied the following transformations: ['obscure_observations_t' 'rescale_t' 'flip_axis_t' 'add_noise_t'] (AugmentAxis)
# INFO    : 2025-08-05 15:25:21,506, astroLuSt.synthetics.dataaugmentation [MainProcess ]: Applied the following transformations: ['obscure_observations_t' 'flip_axis_t' 'shift_features_t' 'add_noise_t'] (AugmentAxis)
# INFO    : 2025-08-05 15:25:21,507, astroLuSt.synthetics.dataaugmentation [MainProcess ]: Applied the following transformations: ['flip_axis_t' 'obscure_observations_t' 'shift_features_t' 'crop_t'] (AugmentAxis)
# INFO    : 2025-08-05 15:25:21,507, astroLuSt.synthetics.dataaugmentation [MainProcess ]: Applied the following transformations: ['obscure_observations_t' 'add_noise_t' 'shift_features_t' 'flip_axis_t'] (AugmentAxis)
# AugmentAxis(
#     nsamples=100,
#     ntransformations=-3, methods=['add_noise_t', 'crop_t', 'flip_axis_t', 'obscure_observations_t', 'rescale_t', 'shift_features_t'], transform_order='unchanged',
#     shift=(0, 20),
#     flip=False,
#     npoints=5, neighbors=False,
#     fill_value_obscure=0, fill_value_range=(0, 1),
#     cutout_start=0, cutout_size=(4, 6),
#     interpkind='linear', fill_value_crop='extrapolate',
#     noise_mag=(0, 0.5),
#     feature_range_min=0, feature_range_max=1,
#     axis=0,
#     seed=None,
#     verbose=1,
# )
# [0. 1. 2.] [0.13 0.32 0.55]

# %% [markdown]
# ### Application on 3d data

# %%
importlib.reload(alsyda)
AA = alsyda.AugmentAxis(
    nsamples=7,
    shift=(0,20), methods=None, transform_order=None,
    npoints=5, neighbors=True,
    fill_value_obscure='random', fill_value_range=(0,1),
    cutout_start=0, cutout_size=(10,15),
    interpkind=None, fill_value_crop=None,
    noise_mag=1,
    feature_range_min=0, feature_range_max=(1,5),
    axis=0,
    seed=None,
    verbose=1,
)
print(AA)


AA.fit(X)
X_new, y_new, y1  = AA.flow(X3d,
    y=y,
    X_misc=[y],
    sample_weights=None, class_weights=[0.1,0.4,0.5],
)


#visualize
fig = plt.figure(figsize=(9,3))
ax1 = fig.add_subplot(111)

#3d
# ax1.plot(X3d[0,:], 'C0:')
ax1.plot(X_new[0,:], 'C0-')
ax1.plot(X_new[1,:], 'C1-')


ax1.set_xlabel('index')
ax1.set_ylabel('y')
plt.show()
# Out:
# INFO    : 2025-08-05 15:25:23,428, astroLuSt.synthetics.dataaugmentation [MainProcess ]: Generating 7 new samples... (AugmentAxis)
# INFO    : 2025-08-05 15:25:23,430, astroLuSt.synthetics.dataaugmentation [MainProcess ]: Applied the following transformations: ['flip_axis_t' 'rescale_t' 'shift_features_t' 'obscure_observations_t'
#  'crop_t' 'add_noise_t'] (AugmentAxis)
# INFO    : 2025-08-05 15:25:23,431, astroLuSt.synthetics.dataaugmentation [MainProcess ]: Applied the following transformations: ['obscure_observations_t' 'add_noise_t' 'rescale_t' 'shift_features_t'
#  'crop_t' 'flip_axis_t'] (AugmentAxis)
# INFO    : 2025-08-05 15:25:23,432, astroLuSt.synthetics.dataaugmentation [MainProcess ]: Applied the following transformations: ['crop_t' 'obscure_observations_t' 'rescale_t' 'flip_axis_t' 'add_noise_t'
#  'shift_features_t'] (AugmentAxis)
# INFO    : 2025-08-05 15:25:23,433, astroLuSt.synthetics.dataaugmentation [MainProcess ]: Applied the following transformations: ['rescale_t' 'obscure_observations_t' 'add_noise_t' 'flip_axis_t'
#  'shift_features_t' 'crop_t'] (AugmentAxis)
# INFO    : 2025-08-05 15:25:23,434, astroLuSt.synthetics.dataaugmentation [MainProcess ]: Applied the following transformations: ['obscure_observations_t' 'add_noise_t' 'rescale_t' 'flip_axis_t'
#  'shift_features_t' 'crop_t'] (AugmentAxis)
# INFO    : 2025-08-05 15:25:23,434, astroLuSt.synthetics.dataaugmentation [MainProcess ]: Applied the following transformations: ['rescale_t' 'crop_t' 'obscure_observations_t' 'add_noise_t' 'flip_axis_t'
#  'shift_features_t'] (AugmentAxis)
# INFO    : 2025-08-05 15:25:23,435, astroLuSt.synthetics.dataaugmentation [MainProcess ]: Applied the following transformations: ['crop_t' 'obscure_observations_t' 'shift_features_t' 'add_noise_t'
#  'rescale_t' 'flip_axis_t'] (AugmentAxis)
# AugmentAxis(
#     nsamples=7,
#     ntransformations=-1, methods=['add_noise_t', 'crop_t', 'flip_axis_t', 'obscure_observations_t', 'rescale_t', 'shift_features_t'], transform_order='unchanged',
#     shift=(0, 20),
#     flip=False,
#     npoints=5, neighbors=True,
#     fill_value_obscure='random', fill_value_range=(0, 1),
#     cutout_start=0, cutout_size=(10, 15),
#     interpkind='linear', fill_value_crop='extrapolate',
#     noise_mag=1,
#     feature_range_min=0, feature_range_max=(1, 5),
#     axis=0,
#     seed=None,
#     verbose=1,
# )
