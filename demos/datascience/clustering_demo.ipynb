# %%
import importlib
import matplotlib.pyplot as plt
import numpy as np
from sklearn.datasets import make_blobs
import sys

sys.path.append("../../")

from astroLuSt.datascience import clustering as aldacl
from astroLuSt.styles import plot_styles as alstps

importlib.reload(aldacl)
importlib.reload(alstps)

#style for plotting
_ = alstps.tre_light()
# Out:
# 2024-11-08 16:48:58.099258: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# # Cluster Metrics

# %% [markdown]
# ## k-dist plot

# %%
importlib.reload(aldacl)

#generate data
X, y = make_blobs(100, 3)

#get kdist-graph
k = 4
kdist = aldacl.kdist(X, k=4)

fig = plt.figure(figsize=(12,5))
ax1 = fig.add_subplot(121)
ax2 = fig.add_subplot(122)
ax1.set_title("Dataset")
ax2.set_title(f"k-Dist Graph")
ax1.scatter(*X[:,:2].T, c=y)
ax2.plot(kdist)
ax1.set_xlabel("x")
ax1.set_ylabel("y")
ax2.set_xlabel("Points")
ax2.set_ylabel(f"{k} Distance")
fig.tight_layout()
