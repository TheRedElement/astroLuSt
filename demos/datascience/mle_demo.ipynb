# %%
import importlib
import matplotlib.pyplot as plt
import numpy as np
from sklearn.datasets import make_blobs
import sys

sys.path.append("../../")

from astroLuSt.datascience import mle as aldaml
from astroLuSt.styles import plot_styles as alstps

importlib.reload(aldaml)
importlib.reload(alstps)

#style for plotting
_ = alstps.tre_light()
# Out:
# 2024-11-08 17:18:48.552977: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# # Maximum-Likelihood Estimate (MLE)

# %%
#generate dataset
X, y = make_blobs(100, n_features=4, centers=1)

# %%
importlib.reload(aldaml)
MLE = aldaml.MLE()

MLE.fit(X, y)

fig = plt.figure(figsize=(16,16))
fig, axs = MLE.plot_result(
    featurenames=[f"x{i}" for i in range(X.shape[1])],
    corner_kwargs=dict(fig=fig, sctr_kwargs=dict(vmin=-1, vmax=1))
)
# fig.tight_layout()
# Out:
# /home/lukas/github/astroLuSt/demos/datascience/../../astroLuSt/visualization/plots.py:424: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), visible=False)
# /home/lukas/github/astroLuSt/demos/datascience/../../astroLuSt/visualization/plots.py:419: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(ax.get_yticklabels(), visible=False)
# /home/lukas/github/astroLuSt/demos/datascience/../../astroLuSt/visualization/plots.py:419: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(ax.get_yticklabels(), visible=False)
# ...
