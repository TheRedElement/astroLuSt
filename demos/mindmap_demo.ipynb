# %% [markdown]
# ## MindMap
# class to generate a Mind Map from a text file

# %%
#%%imports
from datetime import datetime, timedelta, date
import numpy as np
import matplotlib.pyplot as plt

import sys
sys.path.append('..')


from astroLuSt.project_planning import mindmap


import importlib

importlib.reload(mindmap)
# Out:
# <module 'astroLuSt.project_planning.mindmap' from 'c:\\Users\\lukas\\Documents\\GitHub\\astroLuSt\\demos\\..\\astroLuSt\\project_planning\\mindmap.py'>

# %%
#initialize
MM = mindmap.MindMap()

#load data
MM.load(path="TODOs.md")


# print(MM)
fig, ax = MM.draw_MM(
    node_positions=None, node_sizes=1.2, node_colors="jet", node_shape="o", node_borderwidth=0, node_bordercolor="k",     #Nodes
    shift_vmin=0, shift_vmax=0,
    edge_colors="k", edge_styles="-",
    font_size=12, font_color="k",
    plt_style="default",
    section_separation=0.1, spacing=50,
    start_angle=0, end_angle=2,
    correction_exponent=3,
    xmargin=0.1, ymargin=0.15, pad=0.005,
    figsize=(9,5), ax_pos=111,
    save=False, dpi=180,
)
plt.show()
