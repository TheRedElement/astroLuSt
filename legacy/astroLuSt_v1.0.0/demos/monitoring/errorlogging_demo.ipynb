# %%
import importlib
from joblib import Parallel, delayed
import numpy as np
import pandas as pd
import sys
sys.path.append('../../')


from astroLuSt.monitoring import (
    errorlogging as almoer,
    errortesting as almoet,
)

# %% [markdown]
# # LogErrors

# %%
importlib.reload(almoer)

def subfunc(idx):
    n = np.random.choice(range(3), size=1)
    try:
        if n==0:
            almoet.raise_concaterr(n)
        elif n == 1:
            almoet.raise_div0()
        elif n == 2:
            almoet.raise_nested_exception()
    except Exception as e:
        LE.print_exc(e, prefix='Pre', suffix=f'Suf{n}')
        df_le_temp = LE.exc2df(e, prefix='Pre', suffix=f'Suf{idx}', store=True)
            



x = pd.DataFrame(
    columns=['a', 'b'],
#      data=[[1,2],[2,3]]
)

LE = almoer.LogErrors(verbose=0)


_ = Parallel(n_jobs=5, backend='threading')(delayed(subfunc)(idx=idx) for idx in range(5))
    

# print(LE.df_errorlog['exception'].iloc[0])
LE.df_errorlog
# Out:
#                                            exception prefix suffix  \
# 0  Traceback (most recent call last):\n  File "/t...    Pre   Suf3
# 0  Traceback (most recent call last):\n  File "/t...    Pre   Suf3
# 1  Traceback (most recent call last):\n  File "/t...    Pre   Suf4
# 1  Traceback (most recent call last):\n  File "/t...    Pre   Suf4
# 2  Traceback (most recent call last):\n  File "/t...    Pre   Suf0
# 2  Traceback (most recent call last):\n  File "/t...    Pre   Suf0
# 3  Traceback (most recent call last):\n  File "/h...    Pre   Suf1
# 3  Traceback (most recent call last):\n  File "/h...    Pre   Suf1
# 3  Traceback (most recent call last):\n  File "/h...    Pre   Suf1
# 3  Traceback (most recent call last):\n  File "/h...    Pre   Suf1
# 4  Traceback (most recent call last):\n  File "/h...    Pre   Suf2
# 4  Traceback (most recent call last):\n  File "/h...    Pre   Suf2
# 4  Traceback (most recent call last):\n  File "/h...    Pre   Suf2
# 4  Traceback (most recent call last):\n  File "/h...    Pre   Suf2
#
#                                                 file line  \
# 0                  /tmp/ipykernel_18127/880230816.py    7
# 0  /home/lukas/github/astroLuSt/demos/monitoring/...   12
# 1                  /tmp/ipykernel_18127/880230816.py    7
# 1  /home/lukas/github/astroLuSt/demos/monitoring/...   12
# 2                  /tmp/ipykernel_18127/880230816.py    7
# 2  /home/lukas/github/astroLuSt/demos/monitoring/...   12
# 3  /home/lukas/github/astroLuSt/demos/monitoring/...   17
# 3  /home/lukas/github/astroLuSt/demos/monitoring/...   21
# 3                  /tmp/ipykernel_18127/880230816.py   11
# 3  /home/lukas/github/astroLuSt/demos/monitoring/...   23
# 4  /home/lukas/github/astroLuSt/demos/monitoring/...   17
# 4  /home/lukas/github/astroLuSt/demos/monitoring/...   21
# 4                  /tmp/ipykernel_18127/880230816.py   11
# 4  /home/lukas/github/astroLuSt/demos/monitoring/...   23
#
#                                         problem_line  \
# 0                          almoet.raise_concaterr(n)
# 0                        return np.concatenate(n, 0)
# 1                          almoet.raise_concaterr(n)
# 1                        return np.concatenate(n, 0)
# 2                          almoet.raise_concaterr(n)
# 2                        return np.concatenate(n, 0)
# 3                   raise ValueError('custom error')
# 3         raise ValueError('custom error in except')
# 3                    almoet.raise_nested_exception()
# 3  raise ValueError('custom error in except in ex...
# 4                   raise ValueError('custom error')
# 4         raise ValueError('custom error in except')
# 4                    almoet.raise_nested_exception()
# 4  raise ValueError('custom error in except in ex...
#
#                                        error_message  \
# 0  ValueError: zero-dimensional arrays cannot be ...
# 0  ValueError: zero-dimensional arrays cannot be ...
# 1  ValueError: zero-dimensional arrays cannot be ...
# 1  ValueError: zero-dimensional arrays cannot be ...
# 2  ValueError: zero-dimensional arrays cannot be ...
# 2  ValueError: zero-dimensional arrays cannot be ...
# 3       ValueError: custom error in except in except
# 3       ValueError: custom error in except in except
# 3       ValueError: custom error in except in except
# 3       ValueError: custom error in except in except
# 4       ValueError: custom error in except in except
# 4       ValueError: custom error in except in except
# 4       ValueError: custom error in except in except
# 4       ValueError: custom error in except in except
#
#                         time  squeezed
# 0 2024-11-10 17:10:35.384374     False
# 0 2024-11-10 17:10:35.384374     False
# 1 2024-11-10 17:10:35.385588     False
# 1 2024-11-10 17:10:35.385588     False
# 2 2024-11-10 17:10:35.387089     False
# 2 2024-11-10 17:10:35.387089     False
# 3 2024-11-10 17:10:35.388455     False
# 3 2024-11-10 17:10:35.388455     False
# 3 2024-11-10 17:10:35.388455     False
# 3 2024-11-10 17:10:35.388455     False
# 4 2024-11-10 17:10:35.390975     False
# 4 2024-11-10 17:10:35.390975     False
# 4 2024-11-10 17:10:35.390975     False
# 4 2024-11-10 17:10:35.390975     False
