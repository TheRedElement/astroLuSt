# %%
import importlib
import keras
from keras.datasets import mnist
from keras.optimizers import Adam
from keras import layers
from keras import ops
import matplotlib.pyplot as plt
import numpy as np
import os
import sys
import tensorflow as tf

os.environ["KERAS_BACKEND"] = "tensorflow"
sys.path.append("../../")

from astroLuSt.datascience import (
    layers as aldala,
    totables as aldato
)
from astroLuSt.styles import plot_styles as alstps

importlib.reload(alstps)

#style for plotting
_ = alstps.tre_light()

# %% [markdown]
# # `hypergrid2latex()`
# * Convert Hyperparameter Grid to Latex

# %%
hypgrid = dict(
    epochs=100,
    learning_rate=1e-3,
    intermediate_dim=512,
    latent_dim=2,
    beta_1=0.9,
    beta_2=0.999,
    clipnorm=1.0,
)

hypgrid_ltx = aldato.hypergrid2latex(hypergrid=hypgrid)
print(hypgrid_ltx)
# Out:
# \begin{table}[!th]
# \caption{Hyperparameter-Grid}
# \label{tab:YOURLABEL}
# \begin{tabular}{ll}
# \toprule
# Parameter & Value \\
# \midrule
# epochs & 100.0 \\
# learning_rate & 0.001 \\
# intermediate_dim & 512.0 \\
# latent_dim & 2.0 \\
# beta_1 & 0.9 \\
# beta_2 & 0.999 \\
# clipnorm & 1.0 \\
# \bottomrule
# \end{tabular}
# \end{table}

# %% [markdown]
# # `summary2pandas_keras()`
# * storing a `keras` model summary in a `pandas.DataFrame`

# %% [markdown]
# ## Define a Model (VAE)
# * following https://keras.io/examples/generative/vae/ except for custom `Sampling()` layer

# %% [markdown]
# ### Build the encoder

# %%
latent_dim = 2

encoder_inputs = keras.Input(shape=(28, 28, 1))
x = layers.Conv2D(32, 3, activation="relu", strides=2, padding="same")(encoder_inputs)
x = layers.Conv2D(64, 3, activation="relu", strides=2, padding="same")(x)
x = layers.Flatten()(x)
x = layers.Dense(16, activation="relu")(x)
z_mean = layers.Dense(latent_dim, name="z_mean")(x)
z_log_var = layers.Dense(latent_dim, name="z_log_var")(x)
z = aldala.Sampling()([z_mean, z_log_var])
encoder = keras.Model(encoder_inputs, [z_mean, z_log_var, z], name="encoder")
# encoder.summary()

# %% [markdown]
# ### Build the decoder

# %%
latent_inputs = keras.Input(shape=(latent_dim,))
x = layers.Dense(7 * 7 * 64, activation="relu")(latent_inputs)
x = layers.Reshape((7, 7, 64))(x)
x = layers.Conv2DTranspose(64, 3, activation="relu", strides=2, padding="same")(x)
x = layers.Conv2DTranspose(32, 3, activation="relu", strides=2, padding="same")(x)
decoder_outputs = layers.Conv2DTranspose(1, 3, activation="sigmoid", padding="same")(x)
decoder = keras.Model(latent_inputs, decoder_outputs, name="decoder")
# decoder.summary()

# %% [markdown]
# ### Define the VAE as a `Model` with a custom `train_step`

# %%
class VAE(keras.Model):
    def __init__(self, encoder, decoder, **kwargs):
        super().__init__(**kwargs)
        self.encoder = encoder
        self.decoder = decoder
        self.total_loss_tracker = keras.metrics.Mean(name="total_loss")
        self.reconstruction_loss_tracker = keras.metrics.Mean(
            name="reconstruction_loss"
        )
        self.kl_loss_tracker = keras.metrics.Mean(name="kl_loss")

    @property
    def metrics(self):
        return [
            self.total_loss_tracker,
            self.reconstruction_loss_tracker,
            self.kl_loss_tracker,
        ]

    def train_step(self, data):
        with tf.GradientTape() as tape:
            z_mean, z_log_var, z = self.encoder(data)
            reconstruction = self.decoder(z)
            reconstruction_loss = ops.mean(
                ops.sum(
                    keras.losses.binary_crossentropy(data, reconstruction),
                    axis=(1, 2),
                )
            )
            kl_loss = -0.5 * (1 + z_log_var - ops.square(z_mean) - ops.exp(z_log_var))
            kl_loss = ops.mean(ops.sum(kl_loss, axis=1))
            total_loss = reconstruction_loss + kl_loss
        grads = tape.gradient(total_loss, self.trainable_weights)
        self.optimizer.apply_gradients(zip(grads, self.trainable_weights))
        self.total_loss_tracker.update_state(total_loss)
        self.reconstruction_loss_tracker.update_state(reconstruction_loss)
        self.kl_loss_tracker.update_state(kl_loss)
        return {
            "loss": self.total_loss_tracker.result(),
            "reconstruction_loss": self.reconstruction_loss_tracker.result(),
            "kl_loss": self.kl_loss_tracker.result(),
        }

# %%
#combine to VAE
vae = VAE(encoder, decoder)
vae.compile(optimizer=keras.optimizers.Adam())

#train the model
##load the data
(X_train, y_train), (X_test, y_test) = mnist.load_data()

#rescale
X_train = X_train.astype("float32")/255
X_test = X_test.astype("float32")/255

# #test plot
# fig = plt.figure()
# plt.imshow(X_train[0])
# plt.show()

#reshape to 1d
n2use = 10000
X_train = np.expand_dims(X_train, -1)[:n2use]
X_test = np.expand_dims(X_test, -1)[:n2use]
y_train = y_train[:n2use]
y_test = y_test[:n2use]
print(X_train.shape, X_test.shape)

hist = vae.fit(
    X_train, 
    epochs=30,
    batch_size=128,
    callbacks=None
)
# Out:
# (10000, 28, 28, 1) (10000, 28, 28, 1)
# Epoch 1/30
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 7s 72ms/step - kl_loss: 3.3688 - loss: 391.6131 - reconstruction_loss: 388.2443
# Epoch 2/30
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 6s 71ms/step - kl_loss: 2.7423 - loss: 209.1493 - reconstruction_loss: 206.4071
# Epoch 3/30
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 6s 71ms/step - kl_loss: 3.1262 - loss: 200.2981 - reconstruction_loss: 197.1719
# Epoch 4/30
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 6s 71ms/step - kl_loss: 3.2540 - loss: 195.5623 - reconstruction_loss: 192.3083
# Epoch 5/30
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 6s 71ms/step - kl_loss: 3.0747 - loss: 192.5855 - reconstruction_loss: 189.5108
# Epoch 6/30
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 6s 71ms/step - kl_loss: 2.8971 - loss: 190.6864 - reconstruction_loss: 187.7892
# Epoch 7/30
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 6s 71ms/step - kl_loss: 2.7652 - loss: 188.4458 - reconstruction_loss: 185.6805
# Epoch 8/30
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 6s 71ms/step - kl_loss: 2.7008 - loss: 186.5408 - reconstruction_loss: 183.8400
# Epoch 9/30
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 6s 71ms/step - kl_loss: 2.7076 - loss: 184.3460 - reconstruction_loss: 181.6385
# Epoch 10/30
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 6s 71ms/step - kl_loss: 2.7348 - loss: 183.4092 - reconstruction_loss: 180.6744
# Epoch 11/30
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 6s 71ms/step - kl_loss: 2.7700 - loss: 182.7934 - reconstruction_loss: 180.0235
# Epoch 12/30
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 6s 72ms/step - kl_loss: 2.8402 - loss: 181.7854 - reconstruction_loss: 178.9452
# Epoch 13/30
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 6s 71ms/step - kl_loss: 2.8570 - loss: 181.1915 - reconstruction_loss: 178.3344
# Epoch 14/30
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 6s 71ms/step - kl_loss: 2.9803 - loss: 180.2256 - reconstruction_loss: 177.2453
# Epoch 15/30
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 6s 71ms/step - kl_loss: 3.0968 - loss: 180.8010 - reconstruction_loss: 177.7043
# Epoch 16/30
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 6s 71ms/step - kl_loss: 3.3128 - loss: 178.7079 - reconstruction_loss: 175.3951
# Epoch 17/30
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 6s 72ms/step - kl_loss: 3.7530 - loss: 175.9739 - reconstruction_loss: 172.2209
# Epoch 18/30
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 6s 71ms/step - kl_loss: 4.3521 - loss: 171.4500 - reconstruction_loss: 167.0979
# Epoch 19/30
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 6s 71ms/step - kl_loss: 4.7491 - loss: 166.8103 - reconstruction_loss: 162.0612
# Epoch 20/30
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 6s 72ms/step - kl_loss: 4.9401 - loss: 165.0061 - reconstruction_loss: 160.0659
# Epoch 21/30
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 6s 71ms/step - kl_loss: 4.9402 - loss: 164.2090 - reconstruction_loss: 159.2687
# Epoch 22/30
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 6s 72ms/step - kl_loss: 5.1117 - loss: 162.4695 - reconstruction_loss: 157.3578
# Epoch 23/30
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 6s 71ms/step - kl_loss: 5.0894 - loss: 162.1649 - reconstruction_loss: 157.0755
# Epoch 24/30
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 6s 71ms/step - kl_loss: 5.2225 - loss: 160.6328 - reconstruction_loss: 155.4104
# Epoch 25/30
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 6s 72ms/step - kl_loss: 5.2714 - loss: 160.3363 - reconstruction_loss: 155.0650
# Epoch 26/30
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 6s 71ms/step - kl_loss: 5.2823 - loss: 159.2399 - reconstruction_loss: 153.9576
# Epoch 27/30
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 6s 72ms/step - kl_loss: 5.4076 - loss: 158.1581 - reconstruction_loss: 152.7504
# Epoch 28/30
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 6s 72ms/step - kl_loss: 5.3013 - loss: 158.7860 - reconstruction_loss: 153.4847
# Epoch 29/30
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 6s 71ms/step - kl_loss: 5.3857 - loss: 158.8185 - reconstruction_loss: 153.4328
# Epoch 30/30
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 6s 72ms/step - kl_loss: 5.5287 - loss: 157.9678 - reconstruction_loss: 152.4391

# %%
#visualize results
fig = plt.figure(figsize=(9,3))
ax1 = fig.add_subplot(111)
ax1.plot(hist.history["loss"])
ax1.set_xlabel("Epoch")
ax1.set_ylabel("Loss")


z_mu, z_log_var, z = encoder(X_train)

fig = plt.figure(figsize=(9,3))
ax1 = fig.add_subplot(111)
sctr = ax1.scatter(z[:,0], z[:,1], c=y_train, vmin=-1,vmax=10)
cbar = fig.colorbar(sctr, ax=ax1)
ax1.set_xlabel("z1")
ax1.set_ylabel("z2")

X_gen = decoder(tf.constant([[-1,2]]))
fig = plt.figure(figsize=(9,3))
ax1 = fig.add_subplot(111)
ax1.imshow(tf.reshape(X_gen[0], (28, 28)))
plt.show()

plt.show()

# %% [markdown]
# ## Store Model Summary

# %%
importlib.reload(aldato)
df_sum_enc = aldato.summary2pandas_keras(
    model=encoder,
    layer_attrs=["units", "filters", "kernel_size"],
    verbose=0,
)
display(df_sum_enc)
df_sum_dec = aldato.summary2pandas_keras(
    model=decoder,
    layer_attrs=["units", "filters", "kernel_size"],
    verbose=0,
)
display(df_sum_dec)
# Out:
#           name        type         input_shape        output_shape activation  \
# 0  input_layer  InputLayer                       (None, 28, 28, 1)       None
# 1       conv2d      Conv2D   (None, 28, 28, 1)  (None, 14, 14, 32)       relu
# 2     conv2d_1      Conv2D  (None, 14, 14, 32)    (None, 7, 7, 64)       relu
# 3      flatten     Flatten    (None, 7, 7, 64)        (None, 3136)       None
# 4        dense       Dense        (None, 3136)          (None, 16)       relu
# 5       z_mean       Dense          (None, 16)           (None, 2)     linear
# 6    z_log_var       Dense          (None, 16)           (None, 2)     linear
# 7     sampling    Sampling                               (None, 2)       None
#
#    trainable_params  non_trainable_params  total_params  units  filters  \
# 0                 0                     0             0    NaN      NaN
# 1               320                     0           320    NaN     32.0
# 2             18496                     0         18496    NaN     64.0
# 3                 0                     0             0    NaN      NaN
# 4             50192                     0         50192   16.0      NaN
# 5                34                     0            34    2.0      NaN
# 6                34                     0            34    2.0      NaN
# 7                 0                     0             0    NaN      NaN
#
#   kernel_size
# 0        None
# 1      (3, 3)
# 2      (3, 3)
# 3        None
# 4        None
# 5        None
# 6        None
# 7        None
#                  name             type         input_shape  \
# 0       input_layer_1       InputLayer
# 1             dense_1            Dense           (None, 2)
# 2             reshape          Reshape        (None, 3136)
# 3    conv2d_transpose  Conv2DTranspose    (None, 7, 7, 64)
# 4  conv2d_transpose_1  Conv2DTranspose  (None, 14, 14, 64)
# 5  conv2d_transpose_2  Conv2DTranspose  (None, 28, 28, 32)
#
#          output_shape activation  trainable_params  non_trainable_params  \
# 0           (None, 2)       None                 0                     0
# 1        (None, 3136)       relu              9408                     0
# 2    (None, 7, 7, 64)       None                 0                     0
# 3  (None, 14, 14, 64)       relu             36928                     0
# 4  (None, 28, 28, 32)       relu             18464                     0
# 5   (None, 28, 28, 1)    sigmoid               289                     0
#
#    total_params   units  filters kernel_size
# 0             0     NaN      NaN        None
# 1          9408  3136.0      NaN        None
# 2             0     NaN      NaN        None
# 3         36928     NaN     64.0      (3, 3)
# 4         18464     NaN     32.0      (3, 3)
# 5           289     NaN      1.0      (3, 3)
